# %% [markdown]
# ## Context
#
# There is a huge demand for used cars in the Indian Market today. As sales of new cars have slowed down in the recent past, the pre-owned car market has continued to grow over the past years and is larger than the new car market now. Cars4U is a budding tech start-up that aims to find footholes in this market.
#
# In 2018-19, while new car sales were recorded at 3.6 million units, around 4 million second-hand cars were bought and sold. There is a slowdown in new car sales and that could mean that the demand is shifting towards the pre-owned market. In fact, some car sellers replace their old cars with pre-owned cars instead of buying new ones. Unlike new cars, where price and supply are fairly deterministic and managed by OEMs (Original Equipment Manufacturer / except for dealership level discounts which come into play only in the last stage of the customer journey), used cars are very different beasts with huge uncertainty in both pricing and supply. Keeping this in mind, the pricing scheme of these used cars becomes important in order to grow in the market.
#
# As a senior data scientist at Cars4U, you have to come up with a pricing model that can effectively predict the price of used cars and can help the business in devising profitable strategies using differential pricing. For example, if the business knows the market price, it will never sell anything below it.
#
#
# ## Objective
#
# To explore and visualize the dataset, build a linear regression model to predict the prices of used cars, and generate a set of insights and recommendations that will help the business.
#
#
# ## Data Description
#
# The data contains the different attributes of used cars sold in different locations. The detailed data dictionary is given below.
#
# **Data Dictionary**
#
# - Location: Location in which the car is being sold or is available for purchase (cities)
# - Year: Manufacturing year of the car
# - Kilometers_driven: The total kilometers driven in the car by the previous owner(s) in km
# - Fuel_Type: The type of fuel used by the car (Petrol, Diesel, Electric, CNG, LPG)
# - Transmission: The type of transmission used by the car (Automatic/Manual)
# - Owner_Type: Type of ownership
# - Mileage: The standard mileage offered by the car company in kmpl or km/kg
# - Engine: The displacement volume of the engine in CC
# - Power: The maximum power of the engine in bhp
# - Seats: The number of seats in the car
# - New_Price: The price of a new car of the same model in INR Lakhs (1 Lakh = 100,000 INR)
# - Price: The price of the used car in INR Lakhs
# - Brand: The brand name of the car
# - Model: The model name of the car

# %% [markdown]
# ## Let's start coding!

# %% [markdown]
# ### Importing necessary libraries

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns


# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)
import datetime as dt

# to split the data into train and test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# to build linear regression_model
# from sklearn.linear_model import LinearRegression

# to check model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# to suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %%
# loading the dataset
data = pd.read_csv("used_cars_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7251 entries, 0 to 7250
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 7251 non-null   int64
#  1   Location           7251 non-null   object
#  2   Year               7251 non-null   int64
#  3   Kilometers_Driven  7251 non-null   int64
#  4   Fuel_Type          7251 non-null   object
#  5   Transmission       7251 non-null   object
#  6   Owner_Type         7251 non-null   object
#  7   Seats              7198 non-null   float64
#  8   Price              6018 non-null   float64
#  9   mileage            7168 non-null   float64
#  10  engine             7205 non-null   float64
#  11  power              7076 non-null   float64
#  12  new_price          1006 non-null   float64
#  13  Brand              7251 non-null   object
#  14  Model              7251 non-null   object
# dtypes: float64(6), int64(3), object(6)
# memory usage: 849.9+ KB

# %%
data.head()
# Out:
#    id    Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0   0      Mumbai  2010              72000       CNG       Manual      First
# 1   1        Pune  2015              41000    Diesel       Manual      First
# 2   2     Chennai  2011              46000    Petrol       Manual      First
# 3   3     Chennai  2012              87000    Diesel       Manual      First
# 4   4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#    Seats  Price  mileage  engine   power  new_price    Brand   Model
# 0    5.0   1.75    26.60   998.0   58.16        NaN   maruti   wagon
# 1    5.0  12.50    19.67  1582.0  126.20        NaN  hyundai   creta
# 2    5.0   4.50    18.20  1199.0   88.70       8.61    honda    jazz
# 3    7.0   6.00    20.77  1248.0   88.76        NaN   maruti  ertiga
# 4    5.0  17.74    15.20  1968.0  140.80        NaN     audi      a4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7251 entries, 0 to 7250
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 7251 non-null   int64
#  1   Location           7251 non-null   object
#  2   Year               7251 non-null   int64
#  3   Kilometers_Driven  7251 non-null   int64
#  4   Fuel_Type          7251 non-null   object
#  5   Transmission       7251 non-null   object
#  6   Owner_Type         7251 non-null   object
#  7   Seats              7198 non-null   float64
#  8   Price              6018 non-null   float64
#  9   mileage            7168 non-null   float64
#  10  engine             7205 non-null   float64
#  11  power              7076 non-null   float64
#  12  new_price          1006 non-null   float64
#  13  Brand              7251 non-null   object
#  14  Model              7251 non-null   object
# dtypes: float64(6), int64(3), object(6)
# memory usage: 849.9+ KB

# %%
# checking shape of the data
print(f"There are {data.shape[0]} rows and {data.shape[1]} columns.")
# Out:
# There are 7251 rows and 15 columns.

# %%
# let's create a copy of the data to avoid any changes to original data
df = data.copy()

# %%
# checking for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 id         Year  Kilometers_Driven        Seats        Price  \
# count  7251.000000  7251.000000        7251.000000  7198.000000  6018.000000
# mean   3625.678941  2013.365329       57811.654255     5.280495     9.470243
# std    2093.705330     3.254350       37502.061260     0.809376    11.165926
# min       0.000000  1996.000000         171.000000     2.000000     0.440000
# 25%    1812.500000  2011.000000       34000.000000     5.000000     3.500000
# 50%    3626.000000  2014.000000       53416.000000     5.000000     5.640000
# 75%    5438.500000  2016.000000       73000.000000     5.000000     9.950000
# max    7251.000000  2019.000000      775000.000000    10.000000   160.000000
#
#            mileage       engine        power    new_price
# count  7168.000000  7205.000000  7076.000000  1006.000000
# mean     18.347047  1616.399028   112.743949    22.779692
# std       4.158365   595.145170    53.473203    27.759344
# min       6.400000    72.000000    34.200000     3.910000
# 25%      15.300000  1198.000000    75.000000     7.885000
# 50%      18.200000  1493.000000    94.000000    11.570000
# 75%      21.100000  1968.000000   138.100000    26.042500
# max      33.540000  5998.000000   616.000000   375.000000

# %%
df.Year.unique()
# Out:
# array([2010, 2015, 2011, 2012, 2013, 2016, 2018, 2014, 2017, 2007, 2009,
#        2008, 2019, 2006, 2005, 2004, 2002, 2000, 2003, 1999, 2001, 1998,
#        1996], dtype=int64)

# %% [markdown]
# **Before we start exploring the data further, let's quickly check the missingness in the data.**

# %%
dt.datetime.now().year
# Out:
# 2023

# %%
currentyr = dt.datetime.now().year

# %%
df["age"] = currentyr - df["Year"]

# %%
df.head(2)
# Out:
#    id Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0   0   Mumbai  2010              72000       CNG       Manual      First
# 1   1     Pune  2015              41000    Diesel       Manual      First
#
#    Seats  Price  mileage  engine   power  new_price    Brand  Model  age
# 0    5.0   1.75    26.60   998.0   58.16        NaN   maruti  wagon   13
# 1    5.0  12.50    19.67  1582.0  126.20        NaN  hyundai  creta    8

# %%
df.drop(["id", "Year"], axis=1, inplace=True)

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')

# %%
object_cols = df.dtypes[df.dtypes == "object"].index

# %%
object_cols
# Out:
# Index(['Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')

# %%
for column in object_cols:
    print("Categories in",column,"are",df[column].unique())
    print(df[column].nunique()," values exist")
    print("********************")
# Out:
# Categories in Location are ['Mumbai' 'Pune' 'Chennai' 'Coimbatore' 'Hyderabad' 'Jaipur' 'Kochi'
#  'Kolkata' 'Delhi' 'Bangalore' 'Ahmedabad']
# 11  values exist
# ********************
# Categories in Fuel_Type are ['CNG' 'Diesel' 'Petrol' 'LPG' 'Electric']
# 5  values exist
# ********************
# Categories in Transmission are ['Manual' 'Automatic']
# 2  values exist
# ********************
# Categories in Owner_Type are ['First' 'Second' 'Fourth & Above' 'Third']
# 4  values exist
# ********************
# Categories in Brand are ['maruti' 'hyundai' 'honda' 'audi' 'nissan' 'toyota' 'volkswagen' 'tata'
#  'land' 'mitsubishi' 'renault' 'mercedes-benz' 'bmw' 'mahindra' 'ford'
#  'porsche' 'datsun' 'jaguar' 'volvo' 'chevrolet' 'skoda' 'mini' 'fiat'
#  'jeep' 'smart' 'ambassador' 'isuzu' 'force' 'bentley' 'lamborghini'
#  'hindustan' 'opelcorsa']
# 32  values exist
# ********************
# Categories in Model are ['wagon' 'creta' 'jazz' 'ertiga' 'a4' 'eon' 'micra' 'innova' 'vento'
#  'indica' 'ciaz' 'city' 'swift' 'rover' 'pajero' 'amaze' 'duster' 'new'
#  '3' 's' 'a6' 'i20' 'alto' 'wrv' 'corolla' 'ssangyong' 'vitara' 'kuv'
#  'm-class' 'polo' 'nano' 'elantra' 'xcent' 'thar' 'grand' 'kwid' 'i10'
#  'x-trail' 'zen' 'figo' 'c-class' 'cayenne' 'xuv500' 'terrano' 'brio'
#  'fiesta' 'santro' 'zest' 'ritz' '5' 'fortuner' 'ecosport' 'verna' 'go'
#  'omni' 'etios' 'xf' 'eeco' 'civic' 'v40' 'b' 'scorpio' 'cr-v' 'slc' '1'
#  'beat' 'rapid' 'rs5' 'superb' 'x5' 'glc' 'countryman' 'optra' 'lodgy'
#  'e-class' 'baleno' 'laura' 'nuvosport' 'fabia' 'indigo' 'q3' 'octavia'
#  'a8' 'verito' 'cooper' 'santa' 'x1' 'accent' 'tucson' 'gle' 'a-star'
#  'grande' 'x3' 'q7' 'jetta' 'gla' 'celerio' 'sumo' 'accord' '6' 'manza'
#  'spark' 'clubman' 'teana' '800' 'brv' 'xe' 'xenon' 'a3' 'gl-class' 'br-v'
#  's80' 'captur' 'enjoy' 'bolero' 'q5' 'cedia' 's-cross' 'yeti' 'endeavour'
#  'gls' 'a' 'sx4' 'camry' 'mobilio' 'linea' 'tt' 'renault' 'compass' 'ikon'
#  'sail' 'quanto' 'aveo' 'xylo' 'esteem' 'safari' 'ignis' 'xj' 'sunny'
#  'slk-class' 'passat' 'dzire' 'cruze' 'koleos' 'qualis' 'ameo' 'redi-go'
#  'fortwo' 'outlander' 'cayman' 'cla' 'xc60' 'boxster' 'xuv300' 'hexa'
#  'tiago' '7' 'avventura' 'tigor' 's60' 'classic' 'beetle' 'petra' 'getz'
#  'a7' 'elite' 'aspire' 'tiguan' 'captiva' 'punto' 'tuv' 'x6' 'bolt'
#  'evalia' 'scala' 'jeep' 'sonata' 'freestyle' 'logan' 'tavera' 'estilo'
#  'xc90' 'pulse' 'montero' 'panamera' 'crosspolo' 'fluence' 'venture'
#  'nexon' 'mux' 'platinum' 'r-class' 'cls-class' 'd-max' 's-class' 'lancer'
#  'redi' 'e' 'mustang' 'fusion' 'siena' '1000' 'sl-class' 'z4' 'prius'
#  'one' 'versa' 'wr-v' 'continental' 'gallardo' 'f' 'motors' 'flying'
#  'land' 'mu' '370z' 'abarth' '1.4gsi']
# 218  values exist
# ********************

# %%
## 5 times the number of rows than columns

# %%
# looking at value counts for non-numeric features

n = 15  # defining this up here so it's easy to change later

for colname in object_cols:
    val_counts = df[colname].value_counts(normalize=False,dropna=False)  # will also show the NA counts
    print(val_counts[:n])

    if len(val_counts) > n:
        print(f"Only displaying first {n} of {len(val_counts)} values.")
    print("-" * 50, "\n")  # just for more space in between
# Out:
# Mumbai        948
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       590
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: Location, dtype: int64
# --------------------------------------------------
#
# Diesel      3851
# Petrol      3324
# CNG           62
# LPG           12
# Electric       2
# Name: Fuel_Type, dtype: int64
# --------------------------------------------------
#
# Manual       5203
# Automatic    2048
# Name: Transmission, dtype: int64
# --------------------------------------------------
#
# First             5950
# Second            1152
# Third              137
# Fourth & Above      12
# Name: Owner_Type, dtype: int64
# --------------------------------------------------
#
# maruti           1444
# hyundai          1340
# honda             742
# toyota            507
# mercedes-benz     380
# volkswagen        374
# ford              351
# mahindra          331
# bmw               311
# audi              285
# tata              228
# skoda             202
# renault           170
# chevrolet         151
# nissan            117
# Name: Brand, dtype: int64
# Only displaying first 15 of 32 values.
# --------------------------------------------------
#
# swift     418
# city      317
# i20       303
# innova    203
# verna     200
# alto      183
# grand     183
# i10       181
# wagon     178
# polo      178
# xuv500    131
# vento     129
# amaze     127
# new       119
# creta     118
# Name: Model, dtype: int64
# Only displaying first 15 of 218 values.
# --------------------------------------------------

# %% [markdown]
# - We had checked cars of different `Fuel_Type` earlier, but we did not encounter the 2 electric cars. Let us check why.

# %%
df = df[df.Fuel_Type.isin(["Diesel", "Petrol"])]

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %% [markdown]
# ## Data Preprocessing (contd.)

# %% [markdown]
# ### Missing Value Treatment

# %%
# let's check again for missing values
df.isnull().sum()
# Out:
# Location                0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Seats                  53
# Price                1225
# mileage                81
# engine                 46
# power                 174
# new_price            6180
# Brand                   0
# Model                   0
# age                     0
# dtype: int64

# %%
df.shape
# Out:
# (7175, 14)

# %%
df = df[~df['Price'].isnull()]

# %% [markdown]
# **Let's look at a few rows where number of seats is missing.**

# %%
df[df["Seats"].isnull()]
# Out:
#         Location  Kilometers_Driven Fuel_Type Transmission      Owner_Type  \
# 194    Ahmedabad              60006    Petrol       Manual           First
# 208      Kolkata              42001    Petrol       Manual           First
# 229    Bangalore              70436    Diesel       Manual           First
# 733      Chennai              97800    Petrol       Manual           Third
# 749       Mumbai              55001    Diesel    Automatic          Second
# 1294       Delhi              55005    Petrol       Manual           First
# 1327   Hyderabad              50295    Petrol       Manual           First
# 1385        Pune             115000    Petrol       Manual          Second
# 1460  Coimbatore              69078    Petrol       Manual           First
# 1917      Jaipur              88000    Petrol       Manual          Second
# 2074        Pune              24255    Petrol       Manual           First
# 2096  Coimbatore              52146    Petrol       Manual           First
# 2264        Pune              24500    Petrol       Manual          Second
# 2325        Pune              67000    Petrol       Manual           First
# 2334      Mumbai              55000    Petrol       Manual          Second
# 2368     Chennai              56000    Petrol       Manual          Second
# 2529       Kochi              64158    Diesel    Automatic           First
# 2541   Bangalore              65000    Petrol       Manual          Second
# 2622        Pune              95000    Diesel    Automatic          Second
# 2667     Kolkata              32986    Petrol       Manual           First
# 2736      Jaipur             200000    Petrol       Manual           First
# 2779        Pune             100000    Petrol       Manual           First
# 2841   Bangalore              43000    Petrol       Manual           First
# 3271      Mumbai              81000    Diesel    Automatic          Second
# 3403      Jaipur             125000    Petrol       Manual  Fourth & Above
# 3519       Delhi              90000    Diesel    Automatic           First
# 3521       Kochi              66400    Petrol       Manual           First
# 3799      Mumbai             129000    Diesel    Automatic           First
# 3809     Kolkata              27000    Petrol    Automatic           First
# 3881     Kolkata              40000    Petrol       Manual          Second
# 4010        Pune              45271    Diesel       Manual           First
# 4151      Mumbai              75000    Diesel    Automatic          Second
# 4228   Bangalore              79000    Petrol       Manual          Second
# 4576       Delhi              72000    Diesel    Automatic           Third
# 4603        Pune              98000    Petrol       Manual           First
# 4696       Kochi              17941    Petrol       Manual           First
# 4711        Pune              80000    Petrol       Manual          Second
# 4951     Kolkata              47000    Petrol       Manual           First
# 5014       Delhi              63000    Petrol       Manual           First
# 5184       Delhi              52000    Petrol       Manual           First
# 5269   Bangalore              53000    Petrol       Manual          Second
# 5892     Chennai              51000    Petrol       Manual          Second
#
#       Seats  Price  mileage  engine  power  new_price    Brand      Model  age
# 194     NaN   2.95      NaN     NaN    NaN        NaN    honda       city   16
# 208     NaN   2.11    16.10     NaN    NaN        NaN   maruti      swift   13
# 229     NaN   3.60      NaN  1498.0   99.0        NaN     ford       figo    8
# 733     NaN   1.75    16.10     NaN    NaN        NaN   maruti      swift   17
# 749     NaN  26.50      NaN     NaN    NaN        NaN     land      rover   15
# 1294    NaN   3.20    12.80     NaN    NaN        NaN    honda       city   14
# 1327    NaN   5.80    16.10     NaN    NaN        NaN   maruti      swift    8
# 1385    NaN   1.50      NaN     NaN    NaN        NaN    honda       city   19
# 1460    NaN  40.88      NaN     NaN    NaN        NaN     land      rover   15
# 1917    NaN   1.70    13.00  1493.0  100.0        NaN    honda       city   18
# 2074    NaN   3.15    16.10     NaN    NaN        NaN   maruti      swift   12
# 2096    NaN   1.93      NaN     NaN    NaN        NaN  hyundai     santro   19
# 2264    NaN   2.95    18.30     NaN    NaN        NaN   toyota      etios   11
# 2325    NaN   4.70    16.10     NaN    NaN        NaN   maruti      swift    8
# 2334    NaN   1.75    16.10     NaN    NaN        NaN   maruti      swift   16
# 2368    NaN   1.50    19.50  1061.0    NaN        NaN   maruti     estilo   15
# 2529    NaN  17.89    18.48     NaN    NaN        NaN      bmw          5    9
# 2541    NaN   3.15      NaN     NaN    NaN        NaN  hyundai     santro   12
# 2622    NaN  18.00    18.48     NaN    NaN        NaN      bmw          5   11
# 2667    NaN   4.24    16.10     NaN    NaN        NaN   maruti      swift    9
# 2736    NaN   0.70    12.00     NaN    NaN        NaN   maruti      wagon   22
# 2779    NaN   1.60      NaN     NaN    NaN        NaN  hyundai     santro   14
# 2841    NaN   3.25      NaN     NaN    NaN        NaN  hyundai     santro   11
# 3271    NaN  10.50    18.48     NaN    NaN        NaN      bmw          5   15
# 3403    NaN   2.35    16.10     NaN    NaN        NaN   maruti      swift   17
# 3519    NaN  14.50    18.48     NaN    NaN        NaN      bmw          5   11
# 3521    NaN   2.66      NaN     NaN    NaN        NaN  hyundai     santro   11
# 3799    NaN   7.00    12.80  2953.0    NaN        NaN     ford  endeavour   11
# 3809    NaN  11.99    14.00     NaN    NaN        NaN    honda       cr-v   10
# 3881    NaN   2.50    19.50  1061.0    NaN        NaN   maruti     estilo   13
# 4010    NaN   2.60    20.30     NaN    NaN        NaN     fiat      punto   12
# 4151    NaN  16.11      NaN     NaN    NaN        NaN     land      rover   20
# 4228    NaN   1.65    17.00     NaN    NaN        NaN  hyundai     santro   18
# 4576    NaN  13.85    18.48     NaN    NaN        NaN      bmw          5   11
# 4603    NaN   3.15    16.70     NaN    NaN        NaN    honda       jazz   12
# 4696    NaN   3.93    15.70     NaN    NaN        NaN     fiat      punto    6
# 4711    NaN   0.90    17.00     NaN    NaN        NaN  hyundai     santro   20
# 4951    NaN   1.49    14.60     NaN    NaN        NaN     fiat      punto   13
# 5014    NaN   1.60    16.10     NaN    NaN        NaN   maruti      swift   17
# 5184    NaN   3.65    16.10     NaN    NaN        NaN   maruti      swift   11
# 5269    NaN   1.85      NaN     NaN    NaN        NaN    honda       city   21
# 5892    NaN   1.75    19.50  1061.0    NaN        NaN   maruti     estilo   15

# %% [markdown]
# **We'll impute these missing values one-by-one by taking the median number of seats for the particular car using the `Brand` and `Model`.**

# %%
# imputing missing values in Seats
df["Seats"] = df.groupby(["Brand", "Model"])["Seats"].transform(
    lambda x: x.fillna(x.median())
)

# %%
# Checking missing values in Seats
df[df["Seats"].isnull()]
# Out:
#      Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 2368  Chennai              56000    Petrol       Manual     Second    NaN
# 3881  Kolkata              40000    Petrol       Manual     Second    NaN
# 5892  Chennai              51000    Petrol       Manual     Second    NaN
#
#       Price  mileage  engine  power  new_price   Brand   Model  age
# 2368   1.50     19.5  1061.0    NaN        NaN  maruti  estilo   15
# 3881   2.50     19.5  1061.0    NaN        NaN  maruti  estilo   13
# 5892   1.75     19.5  1061.0    NaN        NaN  maruti  estilo   15

# %% [markdown]
# # Clean dataset
# This is to create notes

# %% [markdown]
# * Maruti Estilo can accommodate 5 people.

# %%
df["Seats"] = df["Seats"].fillna(5.0)

# %% [markdown]
# **We will use a similar method to fill missing values for the `Mileage`, `engine_num`, `power_num` columns.**

# %%
cols_list = ["mileage", "engine", "power"]

for col in cols_list:
    df[col] = df.groupby(["Brand", "Model"])[col].transform(
        lambda x: x.fillna(x.median())
    )

df.isnull().sum()
# Out:
# Location                0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Seats                   0
# Price                   0
# mileage                 7
# engine                  0
# power                  11
# new_price            5136
# Brand                   0
# Model                   0
# age                     0
# dtype: int64

# %% [markdown]
# * There are still some missing values in `Mileage`, `power_num`, and `new_price_num`.
# * There are a few car brands and models in our dataset that do not contain the new price information at all.
# * We'll impute these missing values one-by-one by taking the median number of seats for the particular car using the `Brand`.

# %%
cols_list = ["mileage", "power"]

for col in cols_list:
    df[col] = df.groupby(["Brand"])[col].transform(lambda x: x.fillna(x.median()))

df.isnull().sum()
# Out:
# Location                0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Seats                   0
# Price                   0
# mileage                 1
# engine                  0
# power                   1
# new_price            5136
# Brand                   0
# Model                   0
# age                     0
# dtype: int64

# %%
df[df.mileage.isnull()]
# Out:
#     Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 915     Pune             103000    Diesel    Automatic     Second    2.0
#
#      Price  mileage  engine  power  new_price  Brand   Model  age
# 915    3.0      NaN   799.0    NaN        NaN  smart  fortwo   15

# %%
df[df['power'].isnull()]
# Out:
#     Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 915     Pune             103000    Diesel    Automatic     Second    2.0
#
#      Price  mileage  engine  power  new_price  Brand   Model  age
# 915    3.0      NaN   799.0    NaN        NaN  smart  fortwo   15

# %% [markdown]
# * There are still some missing values in `power_num` and `new_price_num`.
# * We'll impute these missing values using the median of the data.

# %%
cols_list = ["power", "mileage"]

for col in cols_list:
    df[col] = df[col].fillna(df[col].median())

df.isnull().sum()
# Out:
# Location                0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Seats                   0
# Price                   0
# mileage                 0
# engine                  0
# power                   0
# new_price            5136
# Brand                   0
# Model                   0
# age                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5950 entries, 1 to 6017
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5950 non-null   object
#  1   Kilometers_Driven  5950 non-null   int64
#  2   Fuel_Type          5950 non-null   object
#  3   Transmission       5950 non-null   object
#  4   Owner_Type         5950 non-null   object
#  5   Seats              5950 non-null   float64
#  6   Price              5950 non-null   float64
#  7   mileage            5950 non-null   float64
#  8   engine             5950 non-null   float64
#  9   power              5950 non-null   float64
#  10  new_price          814 non-null    float64
#  11  Brand              5950 non-null   object
#  12  Model              5950 non-null   object
#  13  age                5950 non-null   int64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 697.3+ KB

# %%
df.corr()
# Out:
#                    Kilometers_Driven     Seats     Price   mileage    engine  \
# Kilometers_Driven           1.000000  0.213481 -0.168788 -0.144525  0.154460
# Seats                       0.213481  1.000000  0.051880 -0.343618  0.397297
# Price                      -0.168788  0.051880  1.000000 -0.334259  0.658094
# mileage                    -0.144525 -0.343618 -0.334259  1.000000 -0.643275
# engine                      0.154460  0.397297  0.658094 -0.643275  1.000000
# power                      -0.003714  0.095213  0.773547 -0.545128  0.864869
# new_price                  -0.003443 -0.013832  0.871256 -0.377185  0.723666
# age                         0.448309 -0.014744 -0.306304 -0.301426  0.049255
#
#                       power  new_price       age
# Kilometers_Driven -0.003714  -0.003443  0.448309
# Seats              0.095213  -0.013832 -0.014744
# Price              0.773547   0.871256 -0.306304
# mileage           -0.545128  -0.377185 -0.301426
# engine             0.864869   0.723666  0.049255
# power              1.000000   0.871094 -0.032609
# new_price          0.871094   1.000000  0.025263
# age               -0.032609   0.025263  1.000000

# %%
sns.heatmap(
    df.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Location                0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Seats                   0
# Price                   0
# mileage                 0
# engine                  0
# power                   0
# new_price            5136
# Brand                   0
# Model                   0
# age                     0
# dtype: int64

# %%
del df['new_price']

# %%
df.isnull().sum()
# Out:
# Location             0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Seats                0
# Price                0
# mileage              0
# engine               0
# power                0
# Brand                0
# Model                0
# age                  0
# dtype: int64

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="green"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="yellow", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### `Price`

# %%
df.columns
# Out:
# Index(['Location', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Seats', 'Price', 'mileage', 'engine', 'power', 'Brand',
#        'Model', 'age'],
#       dtype='object')

# %%
histogram_boxplot(df, "Price", kde=True)
# histogram_boxplot(df, "engine", kde=True)
# histogram_boxplot(df, "Kilometers_Driven", kde=True)
# histogram_boxplot(df, "power", kde=True)
# histogram_boxplot(df, "age", kde=True)

# %%
df[df.power>=250]
# Out:
#         Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 38          Pune              85000    Diesel    Automatic      First    5.0
# 70        Mumbai              73000    Petrol    Automatic      First    5.0
# 107    Hyderabad              78000    Diesel    Automatic     Second    5.0
# 134      Kolkata              13372    Petrol    Automatic      First    2.0
# 148       Mumbai              23000    Petrol    Automatic      First    4.0
# 152      Kolkata              35277    Petrol    Automatic      First    5.0
# 168       Mumbai              41000    Diesel    Automatic      First    5.0
# 264   Coimbatore              29819    Diesel    Automatic      First    5.0
# 271   Coimbatore              51982    Diesel    Automatic      First    5.0
# 326       Mumbai              30000    Diesel    Automatic      First    4.0
# 392   Coimbatore              56451    Diesel    Automatic      First    5.0
# 407    Bangalore              75000    Diesel    Automatic      First    5.0
# 418   Coimbatore              22397    Petrol    Automatic      First    5.0
# 435   Coimbatore              57832    Diesel    Automatic      First    5.0
# 459   Coimbatore              51002    Diesel    Automatic      First    7.0
# 489         Pune             129000    Diesel    Automatic      First    7.0
# 506         Pune             137000    Diesel    Automatic      First    5.0
# 586        Kochi              79926    Diesel    Automatic      First    7.0
# 589    Bangalore              47088    Petrol    Automatic     Second    5.0
# 593       Mumbai              19000    Diesel    Automatic      First    7.0
# 608   Coimbatore              20967    Diesel    Automatic      First    5.0
# 693   Coimbatore              22732    Petrol    Automatic      First    2.0
# 712    Hyderabad              69000    Diesel    Automatic      First    5.0
# 798    Bangalore              10000    Petrol    Automatic      First    2.0
# 842       Mumbai              47000    Diesel    Automatic      First    7.0
# 866   Coimbatore              56652    Diesel    Automatic      First    5.0
# 918    Hyderabad              76000    Diesel    Automatic      First    7.0
# 926    Hyderabad              10000    Petrol       Manual      First    2.0
# 939      Kolkata              43510    Diesel    Automatic      First    5.0
# 1028       Delhi              85000    Diesel    Automatic      First    7.0
# 1038   Bangalore              55000    Diesel    Automatic      First    7.0
# 1078     Kolkata              10512    Petrol    Automatic      First    2.0
# 1088     Kolkata              29000    Diesel    Automatic      First    5.0
# 1093   Bangalore              50000    Diesel    Automatic      First    7.0
# 1123        Pune              66000    Petrol    Automatic     Second    5.0
# 1138   Bangalore              16900    Diesel    Automatic      First    5.0
# 1151   Bangalore              65000    Diesel    Automatic      First    5.0
# 1194      Mumbai              15000    Diesel    Automatic      First    5.0
# 1334      Mumbai              55000    Diesel    Automatic     Second    5.0
# 1352   Bangalore              66538    Diesel    Automatic      First    7.0
# 1379      Jaipur              41493    Diesel    Automatic      First    5.0
# 1397       Kochi              35659    Diesel    Automatic      First    7.0
# 1496       Kochi              17652    Diesel    Automatic      First    5.0
# 1505       Kochi              26013    Diesel    Automatic      First    5.0
# 1596       Delhi              71000    Petrol    Automatic      First    7.0
# 1690  Coimbatore              40129    Diesel    Automatic      First    5.0
# 1691      Mumbai              51000    Diesel    Automatic      First    5.0
# 1741   Hyderabad              58000    Diesel    Automatic      First    4.0
# 1762  Coimbatore              75871    Petrol    Automatic      First    5.0
# 1809   Hyderabad              83000    Diesel    Automatic      First    5.0
# 1830  Coimbatore              33552    Diesel    Automatic      First    5.0
# 1885       Delhi               6000    Diesel    Automatic      First    7.0
# 1924  Coimbatore              27313    Diesel    Automatic      First    5.0
# 1930      Mumbai              55000    Petrol    Automatic      Third    5.0
# 1941      Mumbai              66000    Diesel    Automatic      First    5.0
# 1974  Coimbatore              28060    Petrol    Automatic      First    5.0
# 1984   Bangalore              17465    Petrol    Automatic      First    5.0
# 2056       Kochi              29966    Diesel    Automatic     Second    5.0
# 2089      Mumbai              30000    Diesel    Automatic      First    4.0
# 2095  Coimbatore               2526    Petrol    Automatic      First    2.0
# 2100      Mumbai              35000    Petrol    Automatic     Second    5.0
# 2178      Mumbai              35000    Diesel    Automatic      First    7.0
# 2305      Mumbai               8000    Petrol    Automatic      First    2.0
# 2311  Coimbatore              17738    Diesel    Automatic      First    5.0
# 2319  Coimbatore               9312    Diesel    Automatic      First    5.0
# 2421       Delhi              12000    Diesel    Automatic      First    4.0
# 2476       Kochi              47759    Diesel    Automatic      First    5.0
# 2514       Delhi              21000    Diesel    Automatic     Second    4.0
# 2527       Delhi              59000    Diesel    Automatic      First    7.0
# 2540       Kochi              21603    Diesel    Automatic      First    5.0
# 2546     Chennai              25000    Diesel    Automatic      First    5.0
# 2658     Kolkata              25100    Diesel    Automatic      First    4.0
# 2680   Hyderabad              54000    Petrol    Automatic      First    5.0
# 2705       Kochi              60033    Diesel    Automatic      First    4.0
# 2766  Coimbatore              30706    Diesel    Automatic      First    5.0
# 2786  Coimbatore              73525    Diesel    Automatic      First    5.0
# 2794        Pune              69002    Diesel    Automatic      First    5.0
# 2807      Mumbai              19863    Diesel    Automatic      First    5.0
# 2895       Delhi              48000    Diesel    Automatic     Second    4.0
# 2906   Hyderabad              26000    Diesel    Automatic      First    5.0
# 2977  Coimbatore              42400    Petrol    Automatic      Third    4.0
# 3013  Coimbatore              19254    Diesel    Automatic      First    5.0
# 3050       Delhi              16000    Diesel    Automatic      First    7.0
# 3064      Mumbai              73000    Petrol    Automatic      First    5.0
# 3131       Kochi              14298    Petrol    Automatic      First    5.0
# 3146  Coimbatore              55115    Diesel    Automatic      First    5.0
# 3174  Coimbatore              82536    Diesel    Automatic      First    5.0
# 3198     Kolkata              41100    Diesel    Automatic      First    5.0
# 3241   Bangalore              63000    Diesel    Automatic     Second    5.0
# 3265     Kolkata               7501    Petrol    Automatic      First    4.0
# 3267  Coimbatore              29277    Diesel    Automatic      First    5.0
# 3340       Kochi              50161    Petrol    Automatic      First    5.0
# 3381   Hyderabad              46000    Diesel    Automatic      First    7.0
# 3389      Mumbai              29500    Diesel    Automatic      First    7.0
# 3452  Coimbatore              18090    Diesel    Automatic      First    5.0
# 3488   Bangalore              19828    Diesel    Automatic     Second    4.0
# 3520   Bangalore              98000    Diesel    Automatic     Second    5.0
# 3522   Hyderabad              50000    Diesel    Automatic      First    4.0
# 3579   Hyderabad              29000    Diesel    Automatic      First    4.0
# 3589       Kochi              65266    Diesel    Automatic      First    5.0
# 3751       Kochi              38467    Diesel    Automatic      First    5.0
# 3813      Mumbai              30900    Diesel    Automatic      First    5.0
# 4038      Mumbai              82000    Petrol    Automatic     Second    7.0
# 4054       Delhi              68000    Diesel    Automatic      First    5.0
# 4060      Mumbai              23312    Petrol    Automatic      First    4.0
# 4078   Hyderabad              25000    Diesel    Automatic      First    5.0
# 4100     Chennai              45000    Diesel    Automatic      First    5.0
# 4135      Mumbai              68001    Petrol    Automatic     Second    5.0
# 4165     Chennai              45000    Diesel    Automatic      First    7.0
# 4184       Kochi              54996    Diesel    Automatic      First    4.0
# 4203     Chennai              58000    Diesel    Automatic      First    5.0
# 4341      Mumbai             103000    Petrol    Automatic      First    5.0
# 4359       Kochi              20004    Diesel    Automatic      First    4.0
# 4374  Coimbatore              94521    Diesel    Automatic      First    5.0
# 4386     Chennai              35000    Diesel    Automatic      First    5.0
# 4387   Bangalore              50000    Diesel    Automatic      First    7.0
# 4419  Coimbatore              75668    Diesel    Automatic      First    5.0
# 4450       Kochi              21290    Petrol    Automatic      First    4.0
# 4492     Kolkata              24000    Petrol    Automatic      First    5.0
# 4526     Chennai              29000    Diesel    Automatic      First    5.0
# 4558       Delhi              73000    Diesel    Automatic      First    7.0
# 4613     Chennai              15000    Diesel    Automatic      First    5.0
# 4626       Kochi              65329    Petrol    Automatic      First    4.0
# 4690   Bangalore               3000    Petrol    Automatic     Second    2.0
# 4707   Bangalore              49000    Diesel    Automatic      First    5.0
# 4721     Kolkata              35000    Petrol    Automatic      First    2.0
# 4777   Bangalore              47140    Diesel    Automatic     Second    5.0
# 4789   Hyderabad              53000    Diesel    Automatic      First    5.0
# 4815       Delhi              48000    Petrol    Automatic     Second    5.0
# 4820      Mumbai               5900    Petrol    Automatic      First    4.0
# 4868  Coimbatore              84384    Diesel    Automatic      First    7.0
# 4892       Kochi               9952    Petrol    Automatic      First    2.0
# 4937  Coimbatore              56238    Diesel    Automatic      First    7.0
# 4987   Hyderabad              27000    Diesel    Automatic      First    5.0
# 5087  Coimbatore              43686    Petrol    Automatic      First    4.0
# 5117   Bangalore              28541    Diesel    Automatic      First    5.0
# 5174     Chennai              58000    Diesel    Automatic      First    5.0
# 5293       Delhi              25000    Petrol    Automatic      First    2.0
# 5340  Coimbatore              65003    Diesel    Automatic      First    5.0
# 5413       Kochi              45710    Petrol    Automatic      First    7.0
# 5415  Coimbatore              75995    Diesel    Automatic     Second    5.0
# 5458   Bangalore              28000    Diesel    Automatic      First    5.0
# 5460   Hyderabad              37000    Diesel    Automatic      First    5.0
# 5493      Mumbai              75000    Diesel    Automatic     Second    5.0
# 5520   Hyderabad              48000    Petrol    Automatic      First    4.0
# 5534   Ahmedabad              97003    Diesel    Automatic      First    5.0
# 5544       Delhi              47000    Diesel    Automatic     Second    5.0
# 5551        Pune              88000    Diesel    Automatic      First    5.0
# 5602       Delhi              36400    Diesel    Automatic      First    4.0
# 5701     Chennai              38000    Diesel    Automatic      First    5.0
# 5727     Kolkata              43600    Petrol    Automatic      First    5.0
# 5739     Chennai              21000    Diesel    Automatic     Second    5.0
# 5774      Mumbai              30000    Diesel    Automatic      First    4.0
# 5780       Delhi               6500    Petrol    Automatic      Third    2.0
# 5781   Hyderabad              35000    Diesel    Automatic      First    5.0
# 5802     Chennai             100000    Diesel    Automatic     Second    7.0
# 5884        Pune              93000    Petrol    Automatic     Second    7.0
# 5918   Hyderabad               8000    Petrol    Automatic      First    2.0
# 5945   Bangalore              16000    Diesel    Automatic      First    5.0
# 6007   Hyderabad              40000    Diesel    Automatic     Second    4.0
# 6010   Hyderabad              53000    Petrol    Automatic      First    5.0
#
#        Price  mileage  engine   power          Brand        Model  age
# 38     28.00    11.74  2987.0  254.80  mercedes-benz      m-class   10
# 70     14.50     8.50  4806.0  500.00        porsche      cayenne   15
# 107    24.00    14.74  2993.0  270.90         jaguar           xf   12
# 134    54.00    19.00  2996.0  362.07  mercedes-benz          slc    6
# 148    37.00    11.05  2894.0  444.00           audi          rs5   10
# 152    30.00     7.81  5461.0  362.90  mercedes-benz            s   13
# 168    45.00    15.30  2993.0  258.00            bmw           x5    8
# 264    61.29    11.57  2987.0  254.79  mercedes-benz          gle    6
# 271    45.77    16.55  2993.0  258.00            bmw           x3    6
# 326    49.00     9.52  2993.0  313.00            bmw            6   12
# 392    62.81    13.50  2987.0  282.00  mercedes-benz            s    6
# 407    27.95    14.74  2993.0  270.90         jaguar           xf   10
# 418    70.99    11.50  2996.0  367.00  mercedes-benz          glc    5
# 435    25.82    16.20  2993.0  258.00            bmw            5   12
# 459    48.91    11.33  4134.0  335.20           audi           q7    7
# 489    56.00    11.00  2987.0  258.00  mercedes-benz          gls    6
# 506    18.50    13.50  2987.0  282.00  mercedes-benz            s   13
# 586    29.77    11.33  4134.0  335.20           audi           q7    9
# 589    19.00    10.13  3498.0  364.90  mercedes-benz            s   17
# 593    44.00    15.97  2993.0  258.00            bmw           x5    9
# 608    44.56    14.69  2993.0  258.00            bmw            5    7
# 693    55.54    18.10  3498.0  306.00  mercedes-benz    slk-class    7
# 712    54.00    15.97  2993.0  258.00            bmw           x5    8
# 798    55.00    18.10  3498.0  306.00  mercedes-benz    slk-class    8
# 842    41.50    15.97  2993.0  258.00            bmw           x5    9
# 866    50.29    13.00  2987.0  258.00  mercedes-benz      e-class    5
# 918    58.00    15.97  2993.0  258.00            bmw           x5    7
# 926    40.00     9.00  3436.0  300.00        porsche       cayman   13
# 939    20.50    14.74  2993.0  270.90         jaguar           xf   11
# 1028   38.75    11.30  2987.0  254.80  mercedes-benz     gl-class    9
# 1038   67.00    10.20  4367.0  308.00           land        rover   12
# 1078   64.00     8.60  2706.0  265.00        porsche      boxster    8
# 1088   20.00    14.74  2993.0  270.90         jaguar           xf   11
# 1093   51.00    11.33  4134.0  335.20           audi           q7    9
# 1123   10.75     8.45  2979.0  321.00            bmw            7   15
# 1138   44.00    14.69  2993.0  258.00            bmw            5    8
# 1151   16.00    14.74  2993.0  270.90         jaguar           xf   12
# 1194   69.50    13.00  2987.0  265.00  mercedes-benz      e-class    6
# 1334   19.50    16.46  2993.0  258.00            bmw            7   12
# 1352   70.00    10.20  4367.0  308.00           land        rover   11
# 1379   42.00    13.00  2987.0  265.00  mercedes-benz      e-class    8
# 1397   43.78    15.97  2993.0  258.00            bmw           x5    7
# 1496   58.73    12.90  2993.0  270.88         jaguar           xj    7
# 1505   97.07    12.65  2993.0  255.00           land        rover    4
# 1596   11.99     8.30  4134.0  250.00           audi           q7   15
# 1690   70.80    11.57  2987.0  254.79  mercedes-benz          gle    5
# 1691   22.25    11.74  2987.0  254.80  mercedes-benz      m-class   11
# 1741   48.00    11.20  2993.0  306.00            bmw           x6   10
# 1762   14.12     9.43  2996.0  254.00            bmw            3   12
# 1809   36.00    11.74  2987.0  254.80  mercedes-benz      m-class   11
# 1830   64.87    11.57  2987.0  254.79  mercedes-benz          gle    6
# 1885   79.00    11.00  2987.0  258.00  mercedes-benz          gls    5
# 1924   48.63    14.69  2993.0  258.00            bmw            5    6
# 1930    9.99    10.13  3498.0  364.90  mercedes-benz            s   16
# 1941   21.00    15.30  2993.0  258.00            bmw           x5   11
# 1974   93.67    12.05  2979.0  320.00            bmw            7    5
# 1984   93.00    12.05  2979.0  320.00            bmw            7    6
# 2056   43.60    16.77  2993.0  261.49            bmw            7    8
# 2089   45.00     9.52  2993.0  313.00            bmw            6   10
# 2095   83.96    19.00  2996.0  362.07  mercedes-benz          slc    4
# 2100   32.00    11.90  4806.0  550.00        porsche      cayenne   13
# 2178   41.60    18.00  2993.0  255.00           land        rover    6
# 2305   43.00     9.00  3436.0  300.00        porsche       cayman   12
# 2311   54.45    15.30  2993.0  258.00            bmw           x5    7
# 2319   78.80    18.00  2987.0  258.00  mercedes-benz      e-class    4
# 2421   79.00    10.50  2993.0  271.23         jaguar           xj    7
# 2476   31.80    14.74  2993.0  270.90         jaguar           xf    8
# 2514   44.00    17.54  2993.0  313.00            bmw            6   10
# 2527   36.75    18.00  2993.0  255.00           land        rover    7
# 2540   70.15    13.00  2987.0  265.00  mercedes-benz      e-class    5
# 2546   60.00    15.87  2993.0  308.43            bmw           x6    7
# 2658   75.00    17.85  2967.0  300.00        porsche     panamera    8
# 2680    6.00    13.70  3597.0  262.60          skoda       superb   13
# 2705   51.52    18.18  2967.0  250.00        porsche     panamera    9
# 2766   59.29    11.57  2987.0  254.79  mercedes-benz          gle    5
# 2786   34.54    16.46  2993.0  258.00            bmw            7   10
# 2794   50.00    15.97  2993.0  258.00            bmw           x5    8
# 2807   64.95    11.57  2987.0  254.79  mercedes-benz          gle    6
# 2895   50.50    17.85  2967.0  300.00        porsche     panamera   10
# 2906   75.00    14.47  2993.0  301.73         jaguar           xj    8
# 2977   42.91     8.00  4806.0  394.30        porsche     panamera   13
# 3013   47.70    14.69  2993.0  258.00            bmw            5    7
# 3050   56.00    11.30  2987.0  254.80  mercedes-benz     gl-class    7
# 3064   10.40    10.93  3498.0  272.00  mercedes-benz      e-class   13
# 3131    2.02    13.33  2995.0  340.00        porsche      cayenne    4
# 3146   36.15    14.74  2993.0  270.90         jaguar           xf    7
# 3174   28.63    14.74  2993.0  270.90         jaguar           xf    9
# 3198   26.50    16.77  2993.0  261.49            bmw            7   11
# 3241   65.00    11.49  4367.0  335.30           land        rover   11
# 3265   48.00    10.00  2996.0  333.00  mercedes-benz      e-class    8
# 3267   59.65    11.57  2987.0  254.79  mercedes-benz          gle    5
# 3340   25.93     8.77  4395.0  402.00            bmw            7   13
# 3381   28.00    11.80  2987.0  261.00  mercedes-benz      r-class   13
# 3389   43.00    15.97  2993.0  258.00            bmw           x5    8
# 3452   45.73    16.20  2993.0  258.00            bmw            5    7
# 3488   75.00    17.85  2967.0  300.00        porsche     panamera   10
# 3520   25.00    13.50  2987.0  282.00  mercedes-benz            s   14
# 3522   45.00    12.90  2993.0  271.23         jaguar           xj   11
# 3579   32.00     9.90  3498.0  271.72  mercedes-benz    cls-class   13
# 3589   31.75    14.69  2993.0  258.00            bmw            5    8
# 3751   70.66    12.65  2993.0  255.00           land        rover    8
# 3813   29.50    14.74  2993.0  270.90         jaguar           xf    9
# 4038   16.85    11.80  3498.0  272.00  mercedes-benz      r-class   12
# 4054   27.50    13.00  2987.0  261.50  mercedes-benz      e-class    9
# 4060   40.50    11.05  2894.0  444.00           audi          rs5   10
# 4078  160.00    13.33  2993.0  255.00           land        rover    6
# 4100   57.00    15.97  2993.0  258.00            bmw           x5    7
# 4135   11.75    10.93  3498.0  272.00  mercedes-benz      e-class   14
# 4165   56.00    11.30  2987.0  254.80  mercedes-benz     gl-class    8
# 4184   60.95    17.85  2967.0  300.00        porsche     panamera    8
# 4203   31.00    16.46  2993.0  258.00            bmw            7   13
# 4341    8.85    10.13  3498.0  364.90  mercedes-benz            s   17
# 4359   68.94    17.54  2993.0  313.00            bmw            6    5
# 4374   23.19    14.74  2993.0  270.90         jaguar           xf   11
# 4386   52.00    16.46  2993.0  258.00            bmw            7    9
# 4387   48.00    11.33  4134.0  335.20           audi           q7    8
# 4419   16.58    14.74  2993.0  270.90         jaguar           xf   11
# 4450   56.80    13.00  4951.0  395.00           ford      mustang    5
# 4492    8.75    10.60  2996.0  258.00            bmw            5   13
# 4526   65.00    11.57  2987.0  254.79  mercedes-benz          gle    7
# 4558   17.51    11.33  4134.0  335.20           audi           q7   13
# 4613   70.00    15.97  2993.0  258.00            bmw           x5    6
# 4626   20.72     7.94  4395.0  450.00            bmw            6   13
# 4690   90.00    12.00  5461.0  421.00  mercedes-benz    slk-class    9
# 4707   45.00    16.55  2993.0  258.00            bmw           x3    7
# 4721   29.50     8.10  5461.0  387.30  mercedes-benz     sl-class   13
# 4777   30.00    13.50  2925.0  281.61  mercedes-benz      s-class   12
# 4789   36.00    14.49  2993.0  258.00            bmw            7   14
# 4815    6.99    11.62  2979.0  306.00            bmw            5   17
# 4820   47.50     7.94  4395.0  450.00            bmw            6   12
# 4868   52.54    10.20  4367.0  308.00           land        rover   11
# 4892   58.54    10.37  2979.0  306.00            bmw           z4    5
# 4937   51.69    11.33  4134.0  335.20           audi           q7    8
# 4987   48.00    18.59  2993.0  265.00            bmw            5    7
# 5087   50.66    10.50  5000.0  503.00         jaguar           xj   12
# 5117   60.75    11.57  2987.0  254.79  mercedes-benz          gle    7
# 5174   11.75    18.59  2993.0  265.00            bmw            5   13
# 5293   30.00    10.37  2979.0  306.00            bmw           z4   12
# 5340   67.83    13.60  4134.0  382.00        porsche      cayenne    7
# 5413   23.68    11.80  3498.0  272.00  mercedes-benz      r-class    9
# 5415   65.81    11.49  4367.0  335.30           land        rover   10
# 5458   31.75    13.00  2987.0  258.00  mercedes-benz      e-class    9
# 5460   21.00    13.50  2987.0  282.00  mercedes-benz            s   13
# 5493    9.50    16.46  2993.0  258.00            bmw            7   16
# 5520   59.00     8.60  5998.0  552.00        bentley  continental   17
# 5534   85.00    15.87  2993.0  308.43            bmw           x6    8
# 5544   64.75    12.65  2993.0  255.00           land        rover    9
# 5551   27.00    14.69  2993.0  258.00            bmw            5    9
# 5602   72.00     7.50  4806.0  394.30        porsche     panamera   10
# 5701   45.00    16.46  2993.0  258.00            bmw            7   10
# 5727   10.24    10.93  3498.0  272.00  mercedes-benz      e-class   14
# 5739   55.00    15.97  2993.0  258.00            bmw           x5    6
# 5774   45.00    17.54  2993.0  313.00            bmw            6   10
# 5780  120.00     6.40  5204.0  560.00    lamborghini     gallardo   12
# 5781   29.00    14.74  2993.0  270.90         jaguar           xf   11
# 5802   38.00    11.30  2987.0  254.80  mercedes-benz     gl-class   10
# 5884   15.00    11.80  3498.0  272.00  mercedes-benz      r-class   13
# 5918  100.00    12.50  5000.0  488.10         jaguar            f    8
# 5945   48.00    14.69  2993.0  258.00            bmw            5    7
# 6007   45.00    17.85  2967.0  300.00        porsche     panamera   10
# 6010    4.75    13.70  3597.0  262.60          skoda       superb   14

# %%
# df = df[df.Price<= 60]
#df = df[df.engine<= 3000]
# df = df[df.Kilometers_Driven<= 300000]
# df = df[df.power<= 300]
# df = df[df.age<= 18]

# %%
df.columns
# Out:
# Index(['Location', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Seats', 'Price', 'mileage', 'engine', 'power', 'Brand',
#        'Model', 'age'],
#       dtype='object')

# %% [markdown]
# **Observations**
#
# * This is a highly skewed distribution.
# * Let us use log transformation on this column to see if that helps normalize the distribution.

# %%
df.head()
# Out:
#      Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 1        Pune              41000    Diesel       Manual      First    5.0
# 2     Chennai              46000    Petrol       Manual      First    5.0
# 3     Chennai              87000    Diesel       Manual      First    7.0
# 4  Coimbatore              40670    Diesel    Automatic     Second    5.0
# 6      Jaipur              86999    Diesel       Manual      First    5.0
#
#    Price  mileage  engine   power    Brand   Model  age
# 1  12.50    19.67  1582.0  126.20  hyundai   creta    7
# 2   4.50    18.20  1199.0   88.70    honda    jazz   11
# 3   6.00    20.77  1248.0   88.76   maruti  ertiga   10
# 4  17.74    15.20  1968.0  140.80     audi      a4    9
# 6   3.50    23.08  1461.0   63.10   nissan   micra    9

# %% [markdown]
# - All missing values are dealt with.

# %%
df['Location'].nunique()
# Out:
# 11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5950 entries, 1 to 6017
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5950 non-null   object
#  1   Kilometers_Driven  5950 non-null   int64
#  2   Fuel_Type          5950 non-null   object
#  3   Transmission       5950 non-null   object
#  4   Owner_Type         5950 non-null   object
#  5   Seats              5950 non-null   float64
#  6   Price              5950 non-null   float64
#  7   mileage            5950 non-null   float64
#  8   engine             5950 non-null   float64
#  9   power              5950 non-null   float64
#  10  Brand              5950 non-null   object
#  11  Model              5950 non-null   object
#  12  age                5950 non-null   int64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 650.8+ KB

# %%
df["Brand"].value_counts().index
# Out:
# Index(['maruti', 'hyundai', 'honda', 'toyota', 'volkswagen', 'mercedes-benz',
#        'ford', 'mahindra', 'bmw', 'audi', 'tata', 'skoda', 'renault',
#        'chevrolet', 'nissan', 'land', 'jaguar', 'fiat', 'mini', 'mitsubishi',
#        'volvo', 'jeep', 'datsun', 'porsche', 'isuzu', 'force', 'smart',
#        'ambassador'],
#       dtype='object')

# %%
# checking used ar prices grouped by brand
df.groupby(["Brand"])["Price"].mean().sort_values(ascending=False)
# Out:
# Brand
# lamborghini      120.000000
# bentley           59.000000
# porsche           48.348333
# land              39.259500
# jaguar            37.632250
# mini              26.896923
# mercedes-benz     26.809874
# audi              25.537712
# bmw               25.093684
# volvo             18.802857
# jeep              18.718667
# isuzu             14.696667
# toyota            11.597286
# mitsubishi        11.058889
# force              9.333333
# mahindra           8.027638
# skoda              7.559075
# ford               6.889400
# renault            5.799034
# honda              5.411743
# hyundai            5.363370
# volkswagen         5.307270
# nissan             4.738352
# maruti             4.567545
# tata               3.566250
# fiat               3.269286
# datsun             3.049231
# chevrolet          3.044463
# smart              3.000000
# ambassador         1.350000
# Name: Price, dtype: float64

# %%
affordable_brands = [
    "maruti",
    "hyundai",
    "honda",
    "toyota",
    "volkswagen",
    "ford",
    "mahindra",
    "tata",
    "skoda",
    "renault",
    "chevrolet",
    "nissan",
    "fiat",
    "mitsubishi",
    "mini",
    "jeep",
    "datsun",
    "isuzu",
    "force",
    "smart",
    "ambassador",
]
lux_brand = [
    "mercedes-benz",
    "bmw",
    "audi",
    "land",
    "jaguar",
    "volvo",
    "porsche",
    "bentley",
    "lamborghini",
]

# %%
def car_type(value):
    if value in affordable_brands:
        return 0
    elif value in lux_brand:
        return 1

# %%
df["car_category_binary"] = df["Brand"].apply(car_type)

# %%
df["car_category_binary"].value_counts()
# Out:
# 0    4989
# 1     961
# Name: car_category_binary, dtype: int64

# %%
df.groupby("car_category_binary")["Price"].agg(
    ["mean", "median", "max", "min"]
)
# Out:
#                           mean  median    max   min
# car_category_binary
# 0                     6.055725     4.9   56.8  0.44
# 1                    27.609105    24.0  160.0  2.02

# %%
df["Location"].unique()
# Out:
# array(['Pune', 'Chennai', 'Coimbatore', 'Jaipur', 'Mumbai', 'Kochi',
#        'Kolkata', 'Delhi', 'Bangalore', 'Hyderabad', 'Ahmedabad'],
#       dtype=object)

# %%
tier1_cities = ["Mumbai", "Chennai", "Hyderabad", "Kolkata", "Delhi", "Bangalore"]
tier2_cities = ["Pune", "Coimbatore", "Jaipur", "Kochi", "Ahmedabad"]

# %%
def City_type(value):
    if value in tier1_cities:
        return 1
    elif value in tier2_cities:
        return 0

# %%
df["city_category"] = df["Location"].apply(City_type)

# %%
df["city_category"].value_counts()
# Out:
# 1    3431
# 0    2519
# Name: city_category, dtype: int64

# %%
df.groupby("city_category")["Price"].agg(["mean", "std", "median", "max", "min"])
# Out:
#                     mean        std  median     max   min
# city_category
# 0              10.026332  11.427288    6.00   97.07  0.44
# 1               9.177508  11.035241    5.45  160.00  0.55

# %%
del df["city_category"]

# %%
df.groupby("Location")["Price"].agg(["mean",  "median", "size"])
# Out:
#                  mean  median  size
# Location
# Ahmedabad    8.531312   6.000   221
# Bangalore   13.328631   6.850   358
# Chennai      7.641000   4.500   490
# Coimbatore  15.078223   8.305   636
# Delhi        9.830846   5.670   544
# Hyderabad    9.864393   5.900   733
# Jaipur       5.825036   4.250   411
# Kochi       11.264852   6.790   643
# Kolkata      5.661215   3.750   535
# Mumbai       9.552477   5.850   771
# Pune         6.815411   4.405   608

# %%
df.head()
# Out:
#      Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 1        Pune              41000    Diesel       Manual      First    5.0
# 2     Chennai              46000    Petrol       Manual      First    5.0
# 3     Chennai              87000    Diesel       Manual      First    7.0
# 4  Coimbatore              40670    Diesel    Automatic     Second    5.0
# 6      Jaipur              86999    Diesel       Manual      First    5.0
#
#    Price  mileage  engine   power    Brand   Model  age  car_category_binary
# 1  12.50    19.67  1582.0  126.20  hyundai   creta    8                    0
# 2   4.50    18.20  1199.0   88.70    honda    jazz   12                    0
# 3   6.00    20.77  1248.0   88.76   maruti  ertiga   11                    0
# 4  17.74    15.20  1968.0  140.80     audi      a4   10                    1
# 6   3.50    23.08  1461.0   63.10   nissan   micra   10                    0

# %%
df.columns
# Out:
# Index(['Location', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Seats', 'Price', 'mileage', 'engine', 'power', 'Brand',
#        'Model', 'age', 'car_category_binary'],
#       dtype='object')

# %%
df.drop(["Brand", "Model"], axis=1, inplace=True)

# %%
df.head()
# Out:
#      Location  Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  \
# 1        Pune              41000    Diesel       Manual      First    5.0
# 2     Chennai              46000    Petrol       Manual      First    5.0
# 3     Chennai              87000    Diesel       Manual      First    7.0
# 4  Coimbatore              40670    Diesel    Automatic     Second    5.0
# 6      Jaipur              86999    Diesel       Manual      First    5.0
#
#    Price  mileage  engine   power  age  car_category_binary
# 1  12.50    19.67  1582.0  126.20    8                    0
# 2   4.50    18.20  1199.0   88.70   12                    0
# 3   6.00    20.77  1248.0   88.76   11                    0
# 4  17.74    15.20  1968.0  140.80   10                    1
# 6   3.50    23.08  1461.0   63.10   10                    0

# %%
df2 = pd.get_dummies(
    df,
    columns=df.select_dtypes(include=["object", "category"]).columns.tolist(),
    drop_first=True,
)

# %%
df2.sample(5)
# Out:
#       Kilometers_Driven  Seats  Price  mileage  engine  power  age  \
# 1880              78000    5.0   2.80    17.80  1399.0   68.0   11
# 5526              64005    5.0   4.57    17.71  1197.0   78.9    8
# 1773              15135    5.0   9.29    17.50  1199.0   88.7    5
# 1868              60000    5.0  10.35    15.20  1968.0  140.8   11
# 2464             171000    7.0  16.75    11.50  2982.0  171.0    9
#
#       car_category_binary  Location_Bangalore  Location_Chennai  \
# 1880                    0                   0                 0
# 5526                    0                   0                 0
# 1773                    0                   0                 0
# 1868                    1                   0                 0
# 2464                    0                   1                 0
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 1880                    0               0                   0
# 5526                    1               0                   0
# 1773                    0               0                   0
# 1868                    0               1                   0
# 2464                    0               0                   0
#
#       Location_Jaipur  Location_Kochi  Location_Kolkata  Location_Mumbai  \
# 1880                0               0                 0                0
# 5526                0               0                 0                0
# 1773                0               1                 0                0
# 1868                0               0                 0                0
# 2464                0               0                 0                0
#
#       Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 1880              1                 0                    1
# 5526              0                 1                    1
# 1773              0                 1                    1
# 1868              0                 0                    0
# 2464              0                 0                    1
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 1880                          0                  0                 0
# 5526                          0                  0                 0
# 1773                          0                  0                 0
# 1868                          0                  1                 0
# 2464                          0                  0                 0

# %%
df2.dtypes
# Out:
# Kilometers_Driven              int64
# Seats                        float64
# Price                        float64
# mileage                      float64
# engine                       float64
# power                        float64
# age                            int64
# car_category_binary            int64
# Location_Bangalore             uint8
# Location_Chennai               uint8
# Location_Coimbatore            uint8
# Location_Delhi                 uint8
# Location_Hyderabad             uint8
# Location_Jaipur                uint8
# Location_Kochi                 uint8
# Location_Kolkata               uint8
# Location_Mumbai                uint8
# Location_Pune                  uint8
# Fuel_Type_Petrol               uint8
# Transmission_Manual            uint8
# Owner_Type_Fourth & Above      uint8
# Owner_Type_Second              uint8
# Owner_Type_Third               uint8
# dtype: object

# %%
df2.sample(10)
# Out:
#       Kilometers_Driven  Seats  Price  mileage  engine   power  age  \
# 5306              13000    5.0   6.60    21.40  1197.0   83.10    5
# 726               37630    5.0   9.10    15.63  1499.0  110.40    5
# 5528             105000    5.0   1.75    17.00   999.0   62.10   18
# 2169              96813    8.0   5.50    12.05  2179.0  120.00   13
# 2208              45295    5.0   4.30    18.90   998.0   67.10    8
# 3854              65000    5.0   5.31    19.30  1248.0   73.90    9
# 5706              40175    5.0   6.36    22.54  1396.0   88.73    5
# 4562              43628    5.0   3.16    22.50   998.0   67.04    9
# 1258              40000    5.0  24.00    13.00  2143.0  201.10    9
# 1670              31829    5.0   3.65    21.10   814.0   55.20    6
#
#       car_category_binary  Location_Bangalore  Location_Chennai  \
# 5306                    0                   0                 0
# 726                     0                   0                 0
# 5528                    0                   0                 1
# 2169                    0                   0                 0
# 2208                    0                   0                 0
# 3854                    0                   0                 0
# 5706                    0                   0                 0
# 4562                    0                   0                 0
# 1258                    1                   0                 0
# 1670                    0                   0                 0
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 5306                    0               1                   0
# 726                     0               0                   0
# 5528                    0               0                   0
# 2169                    0               0                   0
# 2208                    0               0                   1
# 3854                    0               0                   0
# 5706                    0               0                   0
# 4562                    0               0                   0
# 1258                    0               1                   0
# 1670                    0               0                   1
#
#       Location_Jaipur  Location_Kochi  Location_Kolkata  Location_Mumbai  \
# 5306                0               0                 0                0
# 726                 0               1                 0                0
# 5528                0               0                 0                0
# 2169                0               0                 0                0
# 2208                0               0                 0                0
# 3854                1               0                 0                0
# 5706                0               1                 0                0
# 4562                0               0                 0                1
# 1258                0               0                 0                0
# 1670                0               0                 0                0
#
#       Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 5306              0                 1                    1
# 726               0                 1                    0
# 5528              0                 1                    1
# 2169              1                 0                    1
# 2208              0                 1                    1
# 3854              0                 0                    1
# 5706              0                 0                    1
# 4562              0                 1                    1
# 1258              0                 0                    0
# 1670              0                 1                    1
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 5306                          0                  0                 0
# 726                           0                  0                 0
# 5528                          0                  0                 0
# 2169                          0                  1                 0
# 2208                          0                  0                 0
# 3854                          0                  0                 0
# 5706                          0                  1                 0
# 4562                          0                  0                 0
# 1258                          0                  0                 0
# 1670                          0                  0                 0

# %%
cols_list = df2.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(15, 10))
sns.heatmap(
    df2[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %%
df2.columns
# Out:
# Index(['Kilometers_Driven', 'Seats', 'Price', 'mileage', 'engine', 'power',
#        'age', 'car_category_binary', 'Location_Bangalore', 'Location_Chennai',
#        'Location_Coimbatore', 'Location_Delhi', 'Location_Hyderabad',
#        'Location_Jaipur', 'Location_Kochi', 'Location_Kolkata',
#        'Location_Mumbai', 'Location_Pune', 'Fuel_Type_Petrol',
#        'Transmission_Manual', 'Owner_Type_Fourth & Above', 'Owner_Type_Second',
#        'Owner_Type_Third'],
#       dtype='object')

# %%
# defining the dependent and independent variables
X = df2.drop(
    [
        "Price",
    ],
    axis=1,
)
y = df2["Price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #prevents data leakage

# %%
scaler = StandardScaler()
x_train_scaled = pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns) 
x_test_scaled = pd.DataFrame(scaler.transform(X_test),columns=X_test.columns)

# %%
x_test_scaled.sample(10)
# Out:
#       Kilometers_Driven     Seats   mileage    engine     power       age  \
# 1512          -1.182722 -0.355186  1.072780 -1.040959 -0.846618  1.022395
# 1093          -0.546755 -0.355186  0.087004  0.561888  1.367570 -1.131201
# 932            0.815562  2.114512 -1.288613  1.431061 -0.230975 -0.823545
# 797            0.584991 -0.355186 -1.335791 -0.223011 -0.241982  2.560678
# 437           -0.081104 -0.355186  0.864202 -0.214749 -0.177409 -0.515888
# 310            0.956467 -0.355186  0.586099 -0.049507 -0.175941  0.099425
# 1572          -1.336436 -0.355186  0.799643 -0.712127 -0.552005 -1.131201
# 1193           0.558988 -0.355186 -0.094260 -0.378339 -0.847352  0.407082
# 623            0.203831 -0.355186  0.864202 -0.214749 -0.177409 -0.515888
# 1301          -1.029007 -0.355186 -0.451821  0.910549  1.366836 -0.208231
#
#       car_category_binary  Location_Bangalore  Location_Chennai  \
# 1512            -0.435500           -0.261195         -0.302419
# 1093             2.296212           -0.261195         -0.302419
# 932             -0.435500           -0.261195          3.306675
# 797             -0.435500           -0.261195         -0.302419
# 437             -0.435500           -0.261195         -0.302419
# 310             -0.435500           -0.261195         -0.302419
# 1572            -0.435500           -0.261195         -0.302419
# 1193            -0.435500           -0.261195         -0.302419
# 623             -0.435500           -0.261195         -0.302419
# 1301             2.296212           -0.261195         -0.302419
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 1512            -0.342376       -0.324593           -0.376875
# 1093             2.920769       -0.324593           -0.376875
# 932             -0.342376       -0.324593           -0.376875
# 797             -0.342376       -0.324593           -0.376875
# 437             -0.342376        3.080777           -0.376875
# 310             -0.342376       -0.324593           -0.376875
# 1572            -0.342376       -0.324593           -0.376875
# 1193            -0.342376       -0.324593           -0.376875
# 623             -0.342376       -0.324593           -0.376875
# 1301            -0.342376       -0.324593           -0.376875
#
#       Location_Jaipur  Location_Kochi  Location_Kolkata  Location_Mumbai  \
# 1512         -0.28209       -0.340622         -0.306655         2.607609
# 1093         -0.28209       -0.340622         -0.306655        -0.383493
# 932          -0.28209       -0.340622         -0.306655        -0.383493
# 797          -0.28209       -0.340622         -0.306655         2.607609
# 437          -0.28209       -0.340622         -0.306655        -0.383493
# 310          -0.28209       -0.340622         -0.306655        -0.383493
# 1572         -0.28209       -0.340622         -0.306655         2.607609
# 1193         -0.28209        2.935803         -0.306655        -0.383493
# 623          -0.28209        2.935803         -0.306655        -0.383493
# 1301         -0.28209       -0.340622          3.260993        -0.383493
#
#       Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 1512      -0.334444          1.067843             0.633572
# 1093      -0.334444         -0.936468            -1.578353
# 932       -0.334444         -0.936468             0.633572
# 797       -0.334444          1.067843             0.633572
# 437       -0.334444         -0.936468            -1.578353
# 310        2.990039         -0.936468             0.633572
# 1572      -0.334444          1.067843             0.633572
# 1193      -0.334444         -0.936468             0.633572
# 623       -0.334444         -0.936468            -1.578353
# 1301      -0.334444         -0.936468            -1.578353
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 1512                  -0.043869          -0.441338         -0.141715
# 1093                  -0.043869          -0.441338         -0.141715
# 932                   -0.043869          -0.441338         -0.141715
# 797                   -0.043869           2.265838         -0.141715
# 437                   -0.043869           2.265838         -0.141715
# 310                   -0.043869          -0.441338         -0.141715
# 1572                  -0.043869          -0.441338         -0.141715
# 1193                  -0.043869          -0.441338         -0.141715
# 623                   -0.043869          -0.441338         -0.141715
# 1301                  -0.043869          -0.441338         -0.141715

# %%
import statsmodels.api as sm

x_train_scaled = sm.add_constant(x_train_scaled)
x_test_scaled = sm.add_constant(x_test_scaled)

# %%
print("Number of rows in train data =", x_train_scaled.shape[0])
print("Number of rows in test data =", x_test_scaled.shape[0])
# Out:
# Number of rows in train data = 4165
# Number of rows in test data = 1785

# %%
x_train_scaled
# Out:
#       const  Kilometers_Driven     Seats   mileage    engine     power  \
# 0       1.0          -0.670341 -0.355186 -0.424507 -0.710475 -0.720775
# 1       1.0           0.514103 -0.355186  1.941851 -0.214749 -0.267664
# 2       1.0          -0.655328 -0.355186  1.067813  0.606503  1.409028
# 3       1.0           0.434761 -0.355186  1.122441 -0.214749 -0.428362
# 4       1.0          -1.221150 -0.355186 -0.193582 -0.216401  0.075379
# ...     ...                ...       ...       ...       ...       ...
# 4160    1.0          -0.038550  2.114512 -0.764687 -0.713780 -0.737285
# 4161    1.0          -0.621639  3.349361 -1.335791  1.431061 -0.205293
# 4162    1.0          -0.081104 -0.355186  1.122441 -0.214749 -0.428362
# 4163    1.0          -1.106889 -0.355186  0.104385 -0.712127 -0.575302
# 4164    1.0           1.584133  2.114512 -1.055205  0.910549  0.455111
#
#            age  car_category_binary  Location_Bangalore  Location_Chennai  \
# 0     0.714738            -0.435500           -0.261195         -0.302419
# 1    -0.515888            -0.435500           -0.261195         -0.302419
# 2    -1.438858             2.296212           -0.261195         -0.302419
# 3    -0.208231            -0.435500           -0.261195         -0.302419
# 4    -0.208231            -0.435500           -0.261195         -0.302419
# ...        ...                  ...                 ...               ...
# 4160  0.407082            -0.435500           -0.261195         -0.302419
# 4161 -1.131201            -0.435500           -0.261195         -0.302419
# 4162 -0.208231            -0.435500           -0.261195         -0.302419
# 4163 -1.438858            -0.435500           -0.261195         -0.302419
# 4164  1.330052            -0.435500           -0.261195          3.306675
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 0               -0.342376       -0.324593           -0.376875
# 1               -0.342376       -0.324593           -0.376875
# 2               -0.342376       -0.324593           -0.376875
# 3               -0.342376        3.080777           -0.376875
# 4               -0.342376       -0.324593           -0.376875
# ...                   ...             ...                 ...
# 4160             2.920769       -0.324593           -0.376875
# 4161            -0.342376       -0.324593           -0.376875
# 4162            -0.342376       -0.324593            2.653402
# 4163            -0.342376       -0.324593           -0.376875
# 4164            -0.342376       -0.324593           -0.376875
#
#       Location_Jaipur  Location_Kochi  Location_Kolkata  Location_Mumbai  \
# 0           -0.282090       -0.340622          3.260993        -0.383493
# 1            3.544965       -0.340622         -0.306655        -0.383493
# 2           -0.282090        2.935803         -0.306655        -0.383493
# 3           -0.282090       -0.340622         -0.306655        -0.383493
# 4           -0.282090       -0.340622         -0.306655         2.607609
# ...               ...             ...               ...              ...
# 4160        -0.282090       -0.340622         -0.306655        -0.383493
# 4161        -0.282090        2.935803         -0.306655        -0.383493
# 4162        -0.282090       -0.340622         -0.306655        -0.383493
# 4163        -0.282090        2.935803         -0.306655        -0.383493
# 4164        -0.282090       -0.340622         -0.306655        -0.383493
#
#       Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 0         -0.334444          1.067843             0.633572
# 1         -0.334444         -0.936468             0.633572
# 2         -0.334444         -0.936468            -1.578353
# 3         -0.334444         -0.936468             0.633572
# 4         -0.334444          1.067843             0.633572
# ...             ...               ...                  ...
# 4160      -0.334444          1.067843             0.633572
# 4161      -0.334444         -0.936468             0.633572
# 4162      -0.334444         -0.936468             0.633572
# 4163      -0.334444          1.067843             0.633572
# 4164      -0.334444         -0.936468             0.633572
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                     -0.043869          -0.441338         -0.141715
# 1                     -0.043869          -0.441338         -0.141715
# 2                     -0.043869          -0.441338         -0.141715
# 3                     -0.043869          -0.441338         -0.141715
# 4                     -0.043869          -0.441338         -0.141715
# ...                         ...                ...               ...
# 4160                  -0.043869          -0.441338         -0.141715
# 4161                  -0.043869          -0.441338         -0.141715
# 4162                  -0.043869          -0.441338         -0.141715
# 4163                  -0.043869          -0.441338         -0.141715
# 4164                  -0.043869           2.265838         -0.141715
#
# [4165 rows x 23 columns]

# %% [markdown]
# ### Check for Multicollinearity
#
# * **Multicollinearity** occurs when predictor variables in a regression model are correlated. This correlation is a problem because predictor variables should be independent.  If the correlation between variables is high, it can cause problems when we fit the model and interpret the results. When we have multicollinearity in the linear model, the coefficients that the model suggests are unreliable.
#
# * There are different ways of detecting (or testing) multi-collinearity, one such way is Variation Inflation Factor.
#
# * **Variance  Inflation  factor**:  Variance  inflation  factors  measures  the  inflation  in  the variances of the regression parameter estimates due to collinearity that exist among the  predictors.  It  is  a  measure  of  how  much  the  variance  of  the  estimated  regression coefficient βk is "inflated" by  the  existence  of  correlation  among  the  predictor variables in the model.
#
# * General Rule of thumb: If VIF is 1 then there is no correlation among the kth predictor and the remaining predictor variables, and  hence  the variance of β̂k is not inflated at all. Whereas if **VIF exceeds 5 or is close to exceeding 5, we say there is moderate VIF and if it is 10 or exceeding 10, it shows signs of high multi-collinearity.**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    # calculating VIF for each feature
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]
    return vif


print(checking_vif(x_train_scaled))
# Out:
#                       feature       VIF
# 0                       const  1.000000
# 1           Kilometers_Driven  1.909366
# 2                       Seats  1.951351
# 3                     mileage  3.625921
# 4                      engine  7.850036
# 5                   power_log  5.677715
# 6                     age_log  2.107319
# 7         car_category_binary  2.575591
# 8          Location_Bangalore  2.448265
# 9            Location_Chennai  2.905329
# 10        Location_Coimbatore  3.359721
# 11             Location_Delhi  2.996331
# 12         Location_Hyderabad  3.659909
# 13            Location_Jaipur  2.591992
# 14             Location_Kochi  3.485964
# 15           Location_Kolkata  3.110317
# 16            Location_Mumbai  3.772314
# 17              Location_Pune  3.291252
# 18           Fuel_Type_Petrol  2.669952
# 19        Transmission_Manual  2.148944
# 20  Owner_Type_Fourth & Above  1.022692
# 21          Owner_Type_Second  1.168525
# 22           Owner_Type_Third  1.096864

# %%
del x_train_scaled['engine']
del x_test_scaled['engine']

# %%
y_train
# Out:
# 1933    1.147402
# 912     1.283708
# 2242    2.617396
# 1637    3.208421
# 763     0.916291
#           ...
# 923     2.384165
# 5306    1.887070
# 4068    3.111291
# 240     0.974560
# 5270    1.728109
# Name: Price_log, Length: 4118, dtype: float64

# %%
x_train_scaled
# Out:
#       const  Kilometers_Driven     Seats   mileage  power_log   age_log  \
# 0       1.0          -0.642229 -0.347725  0.541225   0.039895  0.804842
# 1       1.0          -0.003618  2.204736 -0.803196  -0.826934  0.556270
# 2       1.0           1.568926  2.204736 -1.015734   1.330903  1.031771
# 3       1.0           0.336369 -0.347725 -0.306453   1.328489 -0.775983
# 4       1.0          -0.244221 -0.347725 -0.580774  -0.308561  0.804842
# ...     ...                ...       ...       ...        ...       ...
# 4113    1.0           0.537054  2.204736 -1.692887   1.280734  0.804842
# 4114    1.0          -1.290834 -0.347725  0.753762  -0.506067 -1.833451
# 4115    1.0           0.103078 -0.347725  1.020669   1.541617 -0.025697
# 4116    1.0           0.507572 -0.347725  1.752192  -1.413613  0.281485
# 4117    1.0          -1.312121 -0.347725  1.173894  -1.037823 -1.833451
#
#       car_category_binary  Location_Bangalore  Location_Chennai  \
# 0               -0.433325           -0.256926         -0.299991
# 1               -0.433325           -0.256926         -0.299991
# 2               -0.433325           -0.256926         -0.299991
# 3                2.307738           -0.256926         -0.299991
# 4               -0.433325           -0.256926         -0.299991
# ...                   ...                 ...               ...
# 4113            -0.433325           -0.256926         -0.299991
# 4114            -0.433325           -0.256926         -0.299991
# 4115             2.307738           -0.256926         -0.299991
# 4116            -0.433325           -0.256926         -0.299991
# 4117            -0.433325           -0.256926         -0.299991
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 0               -0.339238       -0.313262           -0.374284
# 1                2.947781       -0.313262           -0.374284
# 2               -0.339238       -0.313262            2.671767
# 3                2.947781       -0.313262           -0.374284
# 4               -0.339238       -0.313262           -0.374284
# ...                   ...             ...                 ...
# 4113            -0.339238        3.192212           -0.374284
# 4114            -0.339238        3.192212           -0.374284
# 4115             2.947781       -0.313262           -0.374284
# 4116            -0.339238       -0.313262           -0.374284
# 4117            -0.339238       -0.313262           -0.374284
#
#       Location_Jaipur  Location_Kochi  Location_Kolkata  Location_Mumbai  \
# 0           -0.271135       -0.349824          3.113857        -0.382670
# 1           -0.271135       -0.349824         -0.321145        -0.382670
# 2           -0.271135       -0.349824         -0.321145        -0.382670
# 3           -0.271135       -0.349824         -0.321145        -0.382670
# 4            3.688202       -0.349824         -0.321145        -0.382670
# ...               ...             ...               ...              ...
# 4113        -0.271135       -0.349824         -0.321145        -0.382670
# 4114        -0.271135       -0.349824         -0.321145        -0.382670
# 4115        -0.271135       -0.349824         -0.321145        -0.382670
# 4116        -0.271135       -0.349824         -0.321145         2.613216
# 4117        -0.271135        2.858582         -0.321145        -0.382670
#
#       Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 0         -0.337009         -0.931436             0.625849
# 1         -0.337009          1.073611             0.625849
# 2         -0.337009         -0.931436             0.625849
# 3         -0.337009         -0.931436            -1.597831
# 4         -0.337009          1.073611             0.625849
# ...             ...               ...                  ...
# 4113      -0.337009         -0.931436             0.625849
# 4114      -0.337009          1.073611             0.625849
# 4115      -0.337009         -0.931436            -1.597831
# 4116      -0.337009         -0.931436             0.625849
# 4117      -0.337009          1.073611            -1.597831
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                     -0.044119           -0.44591         -0.140754
# 1                     -0.044119           -0.44591         -0.140754
# 2                     -0.044119           -0.44591         -0.140754
# 3                     -0.044119           -0.44591         -0.140754
# 4                     -0.044119           -0.44591         -0.140754
# ...                         ...                ...               ...
# 4113                  -0.044119           -0.44591         -0.140754
# 4114                  -0.044119           -0.44591         -0.140754
# 4115                  -0.044119           -0.44591         -0.140754
# 4116                  -0.044119           -0.44591         -0.140754
# 4117                  -0.044119           -0.44591         -0.140754
#
# [4118 rows x 22 columns]

# %%
y_train.index = x_train_scaled.index
y_test.index = x_test_scaled.index

# %%
# create the model
model1 = sm.OLS(y_train, x_train_scaled).fit()

# get the model summary
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Price_log   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     2102.
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        10:22:10   Log-Likelihood:                -469.32
# No. Observations:                4118   AIC:                             976.6
# Df Residuals:                    4099   BIC:                             1097.
# Df Model:                          18
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.8089      0.004    427.064      0.000       1.801       1.817
# Kilometers_Driven      -0.0518      0.006     -8.924      0.000      -0.063      -0.040
# Seats                   0.0536      0.006      9.602      0.000       0.043       0.065
# mileage                -0.0437      0.007     -6.060      0.000      -0.058      -0.030
# power_log               0.4089      0.008     52.616      0.000       0.394       0.424
# age_log                -0.3571      0.006    -59.380      0.000      -0.369      -0.345
# car_category_binary     0.1985      0.007     29.234      0.000       0.185       0.212
# Location_Bangalore      0.0277      0.005      5.898      0.000       0.019       0.037
# Location_Delhi         -0.0201      0.005     -4.172      0.000      -0.030      -0.011
# Location_Hyderabad      0.0316      0.005      6.310      0.000       0.022       0.041
# Location_Jaipur        -0.0205      0.005     -4.341      0.000      -0.030      -0.011
# Location_Kochi         -0.0329      0.005     -6.627      0.000      -0.043      -0.023
# Location_Kolkata       -0.0783      0.005    -15.669      0.000      -0.088      -0.068
# Location_Mumbai        -0.0347      0.005     -6.834      0.000      -0.045      -0.025
# Location_Pune          -0.0287      0.005     -5.852      0.000      -0.038      -0.019
# Fuel_Type_Petrol       -0.1331      0.006    -21.480      0.000      -0.145      -0.121
# Transmission_Manual    -0.0597      0.006     -9.627      0.000      -0.072      -0.048
# Owner_Type_Second      -0.0412      0.005     -9.017      0.000      -0.050      -0.032
# Owner_Type_Third       -0.0314      0.004     -7.123      0.000      -0.040      -0.023
# ==============================================================================
# Omnibus:                     1012.529   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18081.118
# Skew:                          -0.702   Prob(JB):                         0.00
# Kurtosis:                      13.169   Cond. No.                         4.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model1.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
del x_train_scaled["Location_Coimbatore"]
del x_test_scaled["Location_Coimbatore"]

# %%
coef = model1.params

# %%
coef
# Out:
# const                  1.808890
# Kilometers_Driven     -0.051807
# Seats                  0.053626
# mileage               -0.043664
# power_log              0.408872
# age_log               -0.357066
# car_category_binary    0.198505
# Location_Bangalore     0.027725
# Location_Delhi        -0.020115
# Location_Hyderabad     0.031642
# Location_Jaipur       -0.020514
# Location_Kochi        -0.032945
# Location_Kolkata      -0.078296
# Location_Mumbai       -0.034734
# Location_Pune         -0.028724
# Fuel_Type_Petrol      -0.133128
# Transmission_Manual   -0.059717
# Owner_Type_Second     -0.041211
# Owner_Type_Third      -0.031433
# dtype: float64

# %%
# Let us write the equation of the fit
Equation = "log(Price) ="
print(Equation, end="\t")
for i in range(len(coef)):
    print("(", coef[i], ") * ", coef.index[i], "+", end=" ")
# Out:
# log(Price) =	( 1.8088895702322714 ) *  const + ( -0.051806572204896525 ) *  Kilometers_Driven + ( 0.05362623913097328 ) *  Seats + ( -0.04366351603413146 ) *  mileage + ( 0.40887167949176506 ) *  power_log + ( -0.35706612960198525 ) *  age_log + ( 0.1985047996793805 ) *  car_category_binary + ( 0.027724872082763603 ) *  Location_Bangalore + ( -0.020115377976352683 ) *  Location_Delhi + ( 0.031642117084472975 ) *  Location_Hyderabad + ( -0.02051358680261431 ) *  Location_Jaipur + ( -0.03294534672181264 ) *  Location_Kochi + ( -0.07829645093833365 ) *  Location_Kolkata + ( -0.034733571751401265 ) *  Location_Mumbai + ( -0.02872364410633694 ) *  Location_Pune + ( -0.13312842855776155 ) *  Fuel_Type_Petrol + ( -0.05971695478441719 ) *  Transmission_Manual + ( -0.04121144653618277 ) *  Owner_Type_Second + ( -0.03143324456431859 ) *  Owner_Type_Third +

# %%
# function to compute adjusted R-squared
def adj_r2_score(predictors, targets, predictions):
    r2 = r2_score(targets, predictions)
    n = predictors.shape[0]
    k = predictors.shape[1]
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))


# function to compute MAPE
def mape_score(targets, predictions):
    return np.mean(np.abs(targets - predictions) / targets) * 100


# function to compute different metrics to check performance of a regression model
def model_performance_regression(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance

    model: regressor
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    # computing the actual prices by using the exponential function
    target = np.exp(target)
    pred = np.exp(pred)

    r2 = r2_score(target, pred)  # to compute R-squared
    adjr2 = adj_r2_score(predictors, target, pred)  # to compute adjusted R-squared
    rmse = np.sqrt(mean_squared_error(target, pred))  # to compute RMSE
    mae = mean_absolute_error(target, pred)  # to compute MAE
    mape = mape_score(target, pred)  # to compute MAPE

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "RMSE": rmse,
            "MAE": mae,
            "R-squared": r2,
            "Adj. R-squared": adjr2,
            "MAPE": mape,
        },
        index=[0],
    )

    return df_perf

# %%
features = X_train.columns

# %%
# Checking model performance on train set
print("Train Performance:")
lin_reg_model_perf_train = model_performance_regression(model1, x_train_scaled, y_train)
lin_reg_model_perf_train
# Out:
# Train Performance:
#        RMSE       MAE  R-squared  Adj. R-squared       MAPE
# 0  4.219386  1.892029   0.848963        0.848263  21.733954

# %%
# Checking model performance on test set
print("Test Performance:")
lin_reg_model_perf_test = model_performance_regression(model1, x_test_scaled, y_test)
lin_reg_model_perf_test
# Out:
# Test Performance:
#        RMSE       MAE  R-squared  Adj. R-squared       MAPE
# 0  3.826706  1.908917   0.857009        0.855452  21.930931

# %%
import pickle

# %%
pickle.dump(model1, open("predictusedcarprice.model", "wb"))

# %%
model = pickle.load(open("predictusedcarprice.model", "rb"))

# %%
x_test_scaled['prediction'] = np.exp(model1.predict(x_test_scaled))

# %%
int(np.mean(model1.resid))
# Out:
# 0

# %%
x_test_scaled
# Out:
#       const  Kilometers_Driven     Seats   mileage  power_log   age_log  \
# 0       1.0           1.554185 -0.347725  1.752192  -1.413613  0.804842
# 1       1.0          -1.075615 -0.347725 -0.086501   0.347420 -1.833451
# 2       1.0           0.408011 -0.347725 -0.818025   0.039895 -0.373952
# 3       1.0           0.223276 -0.347725  1.413616  -1.035608  0.804842
# 4       1.0           1.280002  2.204736 -1.727486   1.287963 -0.775983
# ...     ...                ...       ...       ...        ...       ...
# 1760    1.0          -0.170516 -0.347725  0.877330  -0.308561  0.556270
# 1761    1.0          -1.054978 -0.347725  0.160635  -0.344588 -0.775983
# 1762    1.0           1.437584  2.204736 -1.075046   0.232935 -0.775983
# 1763    1.0          -0.258962 -0.347725  1.841162  -0.082588 -0.373952
# 1764    1.0           0.641008 -0.347725  1.149180  -0.073564 -1.251484
#
#       car_category_binary  Location_Bangalore  Location_Delhi  \
# 0               -0.433325           -0.256926       -0.313262
# 1               -0.433325           -0.256926       -0.313262
# 2               -0.433325           -0.256926       -0.313262
# 3               -0.433325            3.892174       -0.313262
# 4               -0.433325           -0.256926       -0.313262
# ...                   ...                 ...             ...
# 1760            -0.433325           -0.256926       -0.313262
# 1761            -0.433325           -0.256926       -0.313262
# 1762            -0.433325           -0.256926       -0.313262
# 1763            -0.433325           -0.256926        3.192212
# 1764            -0.433325           -0.256926       -0.313262
#
#       Location_Hyderabad  Location_Jaipur  Location_Kochi  Location_Kolkata  \
# 0              -0.374284        -0.271135       -0.349824         -0.321145
# 1              -0.374284        -0.271135       -0.349824         -0.321145
# 2              -0.374284        -0.271135       -0.349824          3.113857
# 3              -0.374284        -0.271135       -0.349824         -0.321145
# 4              -0.374284        -0.271135       -0.349824         -0.321145
# ...                  ...              ...             ...               ...
# 1760           -0.374284         3.688202       -0.349824         -0.321145
# 1761           -0.374284        -0.271135       -0.349824         -0.321145
# 1762            2.671767        -0.271135       -0.349824         -0.321145
# 1763           -0.374284        -0.271135       -0.349824         -0.321145
# 1764           -0.374284        -0.271135        2.858582         -0.321145
#
#       Location_Mumbai  Location_Pune  Fuel_Type_Petrol  Transmission_Manual  \
# 0            -0.38267      -0.337009         -0.931436             0.625849
# 1            -0.38267      -0.337009          1.073611            -1.597831
# 2            -0.38267      -0.337009          1.073611             0.625849
# 3            -0.38267      -0.337009          1.073611             0.625849
# 4            -0.38267      -0.337009         -0.931436            -1.597831
# ...               ...            ...               ...                  ...
# 1760         -0.38267      -0.337009         -0.931436             0.625849
# 1761         -0.38267       2.967282          1.073611            -1.597831
# 1762         -0.38267      -0.337009         -0.931436             0.625849
# 1763         -0.38267      -0.337009         -0.931436             0.625849
# 1764         -0.38267      -0.337009         -0.931436             0.625849
#
#       Owner_Type_Second  Owner_Type_Third  prediction
# 0              -0.44591          7.104576    1.851609
# 1              -0.44591         -0.140754   13.306708
# 2              -0.44591         -0.140754    4.458140
# 3              -0.44591         -0.140754    2.534997
# 4              -0.44591         -0.140754   19.080485
# ...                 ...               ...         ...
# 1760           -0.44591         -0.140754    4.181670
# 1761           -0.44591         -0.140754    6.177839
# 1762           -0.44591         -0.140754   11.521739
# 1763           -0.44591         -0.140754    6.224290
# 1764           -0.44591         -0.140754    8.116410
#
# [1765 rows x 20 columns]

# %% [markdown]
# * Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE) of train and test data are close, which indicates that our model is not overfitting the train data.
#
# * MAE indicates that our current model is able to predict used car prices within a mean error of 1.3 lakhs on test data.
#
# * The units of both RMSE and MAE are the same, Lakhs in this case. But RMSE is greater than MAE because it penalizes the outliers more.
#
# * MAPE of 12.97 on the test data indicates that the model can predict within 13% of the used car price.
